# %%
import os
import numpy as np
import pandas as pd
import math
import re
from rdkit import Chem

import deepchem as dc
# Out:
# Skipped loading some Tensorflow models, missing a dependency. No module named 'tensorflow'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/home/zhanghanwen/anaconda3/envs/molnet/lib/python3.7/site-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'jax'

# %%
def mksure_path(dirs_or_files):
    if not os.path.exists(dirs_or_files):
        os.makedirs(dirs_or_files)

# %%
# file path
root = "./ChEMBL_data/"
chembl_data_path = root + "in_vitro/"
chembl_pvalue_dataset_path = root + "Datasets/pValue/"
chembl_normpvalue_dataset_path = root + "Datasets/norm_pValue/"

# %%
# function
pvalue_computer = lambda x : round(-np.log10(x*math.pow(10,-9)), 2)
featurizer = dc.feat.CircularFingerprint(size=1024)  # 'ECFP'

# %%
# read SMILES and bioactivities and shape them into a dataset
def loadBiasedData(smiles_path, pro_path):
    smiless = []
    pros = []
    with open(smiles_path) as f:
        smiles = f.readlines()
    with open(pro_path) as f:
        pro = f.readlines()
    assert len(smiles) == len(pro)
    
    for i in range(len(smiles)):
        cur_smi = smiles[i].strip()
        cur_pro = float(pro[i].strip())
        try:
            mol = Chem.MolFromSmiles(cur_smi)
            canonical_smi = Chem.MolToSmiles(mol, isomericSmiles=False)
            smiless.append(canonical_smi)
            pros.append(cur_pro)
        except:
            print(cur_smi)
            continue

    return smiless, pros

# %%
# create a dataset
def CreateDatasets(csv_file_path, pvalue_dir, norm_pvalue_dir):
    test_column = pd.read_csv(csv_file_path, usecols=['assay_type', 'canonical_smiles', 'molecule_chembl_id', 'pchembl_value', 'standard_type', 'standard_value', 'target_chembl_id'])
    # log it
    test_column["pValue"] = test_column["standard_value"].apply(pvalue_computer)
    # normalize it
    denominator = np.max(test_column["pValue"]) - np.min(test_column["pValue"])
    test_column["norm_pValue"] = round((test_column["pValue"] - np.min(test_column["pValue"]))/denominator,2)
    # delete nan
    test_column = test_column.dropna(axis=0,how='any')  
    if len(test_column) < 100:
        print(csv_file_path + ", no 100 number!")
        return 
    # task name
    task_name = [test_column["assay_type"].unique()[0] + "_" + test_column["target_chembl_id"].unique()[0] + "_" + test_column["standard_type"].unique()[0]]

    # create the dataset
    features = featurizer.featurize(test_column["canonical_smiles"])
    print(pvalue_dir)
    pvalue_created_dataset = dc.data.DiskDataset.from_numpy(X=features, y=test_column["pValue"], ids=test_column["canonical_smiles"], 
                                                     tasks = task_name, 
                                                     data_dir=pvalue_dir)
    print(norm_pvalue_dir)
    norm_pvalue_created_dataset = dc.data.DiskDataset.from_numpy(X=features, y=test_column["norm_pValue"], ids=test_column["canonical_smiles"], 
                                                     tasks = task_name, 
                                                     data_dir=norm_pvalue_dir)

# %%
def get_files(chembl_data_path):
    files = []
    for filepath,dirnames,filenames in os.walk(chembl_data_path):
        if len(filenames) != 0:
#             print(filepath)
#             print(filepath.split('/')[-3:])
            assay_type = filepath.split('/')[-3]
            target_type = filepath.split('/')[-2]
            bio_type = filepath.split('/')[-1]
            pvalue_data_dir = chembl_pvalue_dataset_path + assay_type + "/" + \
                 target_type + "/" + bio_type + "/"
            norm_pvalue_data_dir = chembl_normpvalue_dataset_path + assay_type + "/" + \
                 target_type + "/" + bio_type + "/"
#             print(pvalue_data_dir)
#             print(norm_pvalue_data_dir)
        for filename in filenames:
#             print(os.path.join(filepath,filename))
#             print(filename)
#             print()
            cur_target = re.findall('(.*).csv', filename)[0]
#             print(cur_target)
            source_csv_path = os.path.join(filepath,filename)
            goal_pvalue_dir = pvalue_data_dir + cur_target + "/"
            goal_norm_pvalue_dir = norm_pvalue_data_dir + cur_target + "/"
#             print(goal_pvalue_dir)
            mksure_path(goal_pvalue_dir)
#             print(goal_norm_pvalue_dir)
            mksure_path(goal_norm_pvalue_dir)
            # begin to create
            CreateDatasets(source_csv_path, goal_pvalue_dir, goal_norm_pvalue_dir)
            files.append(source_csv_path)
        print("-"*8)
    return files

# %%
def read_chembl_datasets():
    files = []
    pvalue_datasets_list = []
    norm_pvalue_datasets_list = []
    add_filenames = 0
    for filepath,dirnames,filenames in os.walk(chembl_data_path):
        if len(filenames) != 0:
    #             print(filepath)
    #             print(filepath.split('/')[-3:])
            assay_type = filepath.split('/')[-3]
            target_type = filepath.split('/')[-2]
            bio_type = filepath.split('/')[-1]
            pvalue_data_dir = chembl_pvalue_dataset_path + assay_type + "/" + \
                 target_type + "/" + bio_type + "/"
            norm_pvalue_data_dir = chembl_normpvalue_dataset_path + assay_type + "/" + \
                 target_type + "/" + bio_type + "/"
    #             print(pvalue_data_dir)
            print(norm_pvalue_data_dir, len(filenames))
            add_filenames += len(filenames)
        for filename in filenames:
    #             print(os.path.join(filepath,filename))
    #             print(filename)
    #             print()
#             print(filename)
            cur_target = re.findall('(.*).csv', filename)[0]
            print(cur_target)
            source_csv_path = os.path.join(filepath,filename)
            goal_pvalue_dir = pvalue_data_dir + cur_target + "/"
            goal_norm_pvalue_dir = norm_pvalue_data_dir + cur_target + "/"
    #             print(goal_pvalue_dir)
            mksure_path(goal_pvalue_dir)
#             print(goal_norm_pvalue_dir)
            mksure_path(goal_norm_pvalue_dir)
#             print(goal_pvalue_dir)
            pvalue_datasets_list.append(dc.data.DiskDataset(goal_pvalue_dir))
#             print(dc.data.DiskDataset(goal_pvalue_dir))
            norm_pvalue_datasets_list.append(dc.data.DiskDataset(goal_norm_pvalue_dir))
            print(filename, dc.data.DiskDataset(goal_norm_pvalue_dir).get_task_names())
            files.append(source_csv_path)
    #         break
        print("-"*8)
    print(add_filenames)
    
    return files, pvalue_datasets_list, norm_pvalue_datasets_list

# %%
print(len(files))
# Out:
# 1395

# %%
len(files), len(pvalue_datasets_list), len(norm_pvalue_datasets_list)
# Out:
# (1395, 1395, 1395)

# %%
pvalue_datasets_list[8].get_task_names()
# Out:
# array(['F_CHEMBL3371_IC50'], dtype='<U17')

# %%
"0: " + pvalue_datasets_list[0].get_task_names()[0]
# Out:
# '0: F_CHEMBL4333_IC50'

# %%
pvalue_datasets_list[8].y
# Out:
# array([6.1 , 6.52, 9.1 , 7.95, 7.85, 7.51, 8.05, 6.77, 8.39, 8.01, 7.47,
#        9.4 , 8.77, 7.71, 8.07, 7.86, 9.15, 8.41, 8.03, 7.37, 7.83, 7.37,
#        8.06, 8.57, 8.89, 9.1 , 7.85, 8.8 , 7.67, 7.59, 7.68, 7.98, 8.96,
#        8.14, 8.12, 9.22, 7.09, 7.12, 7.02, 8.09, 7.31, 7.25, 7.61, 8.14,
#        9.1 , 9.  , 6.95, 7.96, 7.27, 7.28, 7.07, 7.36, 7.81, 6.97, 7.01,
#        7.68, 6.91, 7.6 , 7.21, 6.96, 6.96, 7.3 , 8.  , 7.59, 6.19, 7.96,
#        6.92, 6.88, 7.25, 7.64, 7.02, 6.85, 7.04, 6.67, 6.73, 6.87, 6.47,
#        7.59, 8.1 , 6.31, 7.3 , 6.47, 7.15, 7.55, 6.17, 7.76, 8.02, 6.21,
#        6.9 , 6.79, 7.96, 7.59, 7.28, 6.59, 6.77, 8.1 , 8.  , 6.92, 6.61,
#        6.98, 7.11, 7.02, 6.93, 7.  , 5.8 , 7.28, 6.24, 7.02, 7.24, 7.33,
#        6.62, 7.27, 6.75, 7.39, 6.41, 6.53, 6.08, 6.71, 8.21, 8.08, 7.82,
#        8.27, 5.8 , 5.62, 7.67, 7.27, 6.49, 6.06, 5.94, 5.98, 6.01, 5.63,
#        4.68, 5.95, 5.64, 6.16, 6.18, 5.39, 6.01, 6.56, 6.8 , 5.43, 5.7 ,
#        5.82, 5.25, 5.53, 5.84, 5.76, 6.  , 6.26, 5.55, 6.74, 6.04, 5.77,
#        7.06, 5.59, 5.24, 7.55, 7.05, 7.57, 7.15, 7.47, 7.29, 7.9 , 7.8 ,
#        7.78, 7.4 , 7.76, 6.5 , 6.8 , 6.69, 6.35, 6.42, 6.36, 7.74, 6.97,
#        7.03, 7.77, 7.1 , 6.97, 7.22, 7.09, 7.12, 8.22, 8.12, 7.01, 7.77,
#        8.11, 6.05, 4.59, 4.21, 7.82, 5.41, 7.07, 5.47, 7.11, 6.21, 4.55,
#        8.22, 6.43, 7.16, 6.72, 6.59, 5.94, 5.97, 6.06, 6.24, 5.83, 6.02,
#        5.8 , 5.98, 5.72, 6.16, 6.33, 7.22, 7.17, 6.96, 6.11, 6.82, 6.09,
#        5.91, 6.24, 5.92, 5.66, 6.21, 5.91, 6.46, 6.07, 6.07, 5.89, 6.17,
#        5.91, 6.12, 7.34, 5.8 , 5.62, 6.17, 7.23, 7.49, 6.54, 5.86, 6.16,
#        5.93, 7.43, 6.54, 6.77, 6.59, 6.24, 6.92, 5.66, 6.13, 6.74, 5.9 ,
#        6.52, 5.74, 6.11, 6.32, 6.82, 6.27, 6.57, 5.94, 6.55, 5.92, 6.24,
#        6.03, 6.27, 5.71, 6.24, 6.77, 5.83, 5.96, 6.22, 6.33, 6.28, 5.88,
#        7.2 , 7.4 , 6.96, 6.59, 6.3 , 6.6 , 6.3 , 6.66, 7.54, 6.72, 6.82,
#        5.9 , 6.32, 6.39, 6.19, 5.79, 6.05, 6.15, 6.11, 7.05, 6.85, 6.7 ,
#        6.77, 5.69, 6.14, 6.1 , 6.77, 7.16, 6.85, 6.02, 6.23, 6.09, 6.46,
#        5.3 , 6.09, 6.22, 5.28, 5.86, 5.42, 6.23, 5.76, 6.23, 6.05, 6.  ,
#        5.95, 6.04, 5.97, 5.92, 5.6 , 6.13, 5.94, 6.1 , 5.7 , 5.87, 6.07,
#        5.84, 5.65, 5.69, 5.7 , 5.7 , 5.95, 5.81, 5.98, 5.82, 5.7 , 5.71,
#        5.87, 6.04, 7.46, 8.06, 7.27, 6.88, 6.33, 7.  , 7.21, 6.97, 7.24,
#        6.26, 7.42, 6.95, 6.48, 7.4 , 8.1 , 7.89, 7.77, 8.54, 8.77, 8.8 ,
#        8.77, 8.72, 8.74, 8.66, 8.74, 8.54, 8.85, 8.34, 8.7 , 8.12, 8.49,
#        6.73, 7.89, 7.52, 6.99, 7.06, 7.03, 7.25, 7.82, 6.9 , 7.03, 7.92,
#        7.72, 6.93, 7.36, 7.85, 7.57, 6.9 , 7.8 , 7.06, 7.02, 7.68, 6.76,
#        7.06, 8.42, 6.34, 7.05, 7.64, 6.86, 8.09, 7.32, 6.99, 6.81, 7.04,
#        7.72, 6.51, 6.53, 6.49, 5.82, 5.75, 6.12, 6.97, 6.6 , 6.99, 6.43,
#        6.36, 6.07, 6.05, 5.98, 5.8 , 5.69, 5.53, 5.49, 5.36, 5.24, 5.22,
#        5.19, 5.13, 5.08, 5.05, 4.97, 4.8 , 4.36, 8.01, 7.49, 8.17, 7.27,
#        7.16, 7.93, 7.47, 7.68, 8.44, 8.07, 6.75, 6.88, 6.87, 7.48, 7.57,
#        6.64, 6.45, 6.55, 6.51, 6.61, 5.87, 7.02, 6.1 , 7.2 , 7.4 , 8.22,
#        7.17, 7.35, 6.44, 5.44, 6.36, 5.71, 6.34, 5.69, 6.63, 6.87, 7.72,
#        6.51, 6.11, 5.15, 6.24, 5.78, 5.17, 5.48, 5.28, 8.4 , 5.42, 5.44,
#        5.85, 5.18, 5.54, 5.13, 5.74, 5.69, 5.32, 5.62, 7.82, 8.1 , 7.96,
#        5.74, 5.3 , 5.2 , 5.67, 6.13, 5.85, 5.61, 5.53, 5.6 , 5.69, 5.41,
#        6.44, 8.33, 8.33, 6.52, 5.08, 6.29, 5.28, 6.33, 6.04, 5.66, 5.73,
#        6.35, 6.  , 6.73, 5.95, 6.81, 6.38, 7.14, 6.75, 4.52, 7.28, 6.14,
#        7.12, 7.35, 7.62, 7.8 , 8.52, 7.  , 8.4 , 8.4 , 7.72, 8.4 , 5.98,
#        6.47, 7.92, 7.92, 8.05, 7.92, 5.81, 6.76, 6.71, 6.76, 5.73, 5.77,
#        5.64, 5.22, 7.95, 8.05, 7.35, 7.11, 8.  , 7.6 , 7.59, 7.66, 7.25,
#        7.57, 7.46, 7.49, 6.32, 8.11, 8.3 , 5.93, 8.22, 8.3 , 8.7 , 8.4 ,
#        4.96, 5.06, 5.4 , 5.25, 5.61, 5.48, 5.85, 5.75, 6.51, 7.75, 7.28,
#        7.16, 7.25, 8.55, 6.75, 7.7 , 7.4 , 7.69, 6.07, 7.01, 6.  , 5.7 ,
#        8.55, 8.18, 8.27, 8.19, 8.28, 7.97, 6.46, 8.55, 7.01])

# %%
set(pvalue_datasets_list[0].ids)
# Out:
# {'C=C1C(=O)C=C2CN(C(=O)c3ccccc3)[C@@](Cc3ccc(F)cc3)(C(=O)OC)[C@@H]12',
#  'C=CCn1c(O)nnc1Sc1ncc([N+](=O)[O-])s1',
#  'CC(=O)Cn1ncc(Br)c(Br)c1=O',
#  'CC(=O)N(C1=C(Cl)C(=O)c2ccccc2C1=O)C1CCCCC1',
#  'CC(=O)n1cc(N(C(=O)CCl)c2ccc(C)cc2)c2ccccc21',
#  'CC(=O)n1cc(N(C(=O)CCl)c2ccc(Cl)cc2)c2ccccc21',
#  'CC(C)(C)C(=O)/C(=C\\c1cccc([N+](=O)[O-])c1)n1cncn1',
#  'CC(C)(C)c1ccc(-n2nc(C#N)c(Cl)cc2=O)cc1',
#  'CC(C)Oc1ccc(COc2ccc3c(c2)c(Cl)c2n3CCOC2CC(=O)O)cc1C#N',
#  'CC(C)c1nnc(NC(=O)CCS(=O)(=O)c2nc(-c3cccs3)cc(C(F)(F)F)n2)s1',
#  'CC1(C)C[C@H]2C=C(C=O)[C@]3(C=O)C[C@]3(C)[C@H]2C1',
#  'CC1=CC2/C=C(\\C)CCC(O)C(O)/C=C/C(=O)C23C(=O)NC(CC(C)C)C3C1C',
#  'CC1=NNC(=O)/C1=C\\c1cn(-c2ccccc2)nc1-c1ccccc1',
#  'CCC(Nc1cc(C)cc(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCC(Nc1cc(C)cc(CN2CC[C@@H](C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCC(Nc1ccc(C)c(C(C)N2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCC(Nc1ccc(C)c(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCC(Nc1cccc(C(C)N2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCC(Nc1cccc(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCC(Nc1cccc(CN2CC[C@@H](C(=O)O)C2)c1C)c1ccc(Cl)c(C)c1',
#  'CCC(c1cccc(N[C@H](CC)c2ccc(Cl)c(C)c2)c1)N1CC(C(=O)O)C1',
#  'CCC/N=C1\\S/C(=C\\c2ccc(C(=O)NCCO)cc2)C(=O)N1c1ccccc1C',
#  'CCC/N=C1\\S/C(=C\\c2ccc(C(=O)OC)c(Cl)c2)C(=O)N1c1ccccc1C',
#  'CCC/N=C1\\S/C(=C\\c2ccc(C(=O)OC)cc2)C(=O)N1c1ccccc1C',
#  'CCC/N=C1\\S/C(=C\\c2ccc(C(=O)OCCO)cc2)C(=O)N1c1ccccc1C',
#  'CCC/N=C1\\S/C(=C\\c2ccc(OC[C@H](O)CO)c(Cl)c2)C(=O)N1c1ccccc1C',
#  'CCCCCCCCCCC#CC(C)(O)c1ccccc1-c1ccc(Sc2ccc(OCCCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(N)c1ccccc1-c1ccc(Sc2ccc(OCCCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccc(-c2ccc(Oc3ccc(OCC)cc3)c(S(=O)(=O)[O-])c2)s1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1cccc(-c2ccc(Oc3ccc(OCC)cc3)c(S(=O)(=O)[O-])c2)c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Oc2ccc(OCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Oc2ccccc2OCC)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Sc2ccc(OC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Sc2ccc(OCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Sc2ccc(OCCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Sc2ccc(OCCCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1ccccc1-c1ccc(Sc2ccc(OCCCCCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCC#CC(O)c1sccc1-c1ccc(Oc2ccc(OCC)cc2)c(S(=O)(=O)[O-])c1.[Na+]',
#  'CCCCCCCCCCCCCCCCCC1=NN(c2ccc(Oc3ccc(OCC)cc3)c(S(=O)(=O)[O-])c2)C(=O)C1.[Na+]',
#  'CCCCCCCCCCCCCCCCOc1ccc(/C(=N/NS(=O)(=O)c2cc(C(=O)O)cc(C(=O)O)c2)N2CCCCC2)cc1OC',
#  'CCCCCCCCCCCCCCCCOc1ccc(/C(=N/NS(=O)(=O)c2cc(C(=O)O)cc(C(=O)O)c2)c2ccccc2)cc1OC',
#  'CCCCCCCCCCCCCCCCOc1ccc(/C(=N\\NS(=O)(=O)c2cc(C(=O)O)cc(C(=O)O)c2)c2ccccc2)cc1OC',
#  'CCCCCCCCc1ccc(CC[C@](N)(CO)COP(=O)(O)O)cc1',
#  'CCCCOc1ccc(Sc2ccc(-c3ccccc3C(O)C#CCCCCCCCCCCO)cc2S(=O)(=O)O)cc1',
#  'CCCCOc1ccc(Sc2ccc(-c3ccccc3C(O)C#CCOCCCCCCCCCCCO)cc2S(=O)(=O)[O-])cc1.[Na+]',
#  'CCCCOc1ccc(Sc2ccc(-c3ccccc3C(O)C#CCOCCCCCCCCCO)cc2S(=O)(=O)[O-])cc1.[Na+]',
#  'CCCCOc1ccc(Sc2ccc(-c3ccccc3C(O)C#CCOCCCCCCCO)cc2S(=O)(=O)[O-])cc1.[Na+]',
#  'CCCCOc1ccc(Sc2ccc(-c3ccccc3C(O)C#CCOCCCCCO)cc2S(=O)(=O)[O-])cc1.[Na+]',
#  'CCCCS(=O)(=O)/C=C\\C=C/S(=O)(=O)CCCC',
#  'CCCS(=O)(=O)c1nnnn1-c1cccc(OC)c1',
#  'CCOC(=O)/C(=C\\c1ccc(OC(F)F)cc1)C1=Nn2c(nnc2-c2ccc(Cl)cc2)SC1',
#  'CCOC(=O)C(=Cc1ccc(Br)cc1)C(=O)OCC',
#  'CCOC(=O)CCS(=O)(=O)c1nc(-c2ccccc2)cc(C(F)(F)F)n1',
#  'CCOC(=O)COc1ccccc1/C=C\\[N+](=O)[O-]',
#  'CCOC(=O)c1ccc(NC(=O)Cn2ncc(Cl)c(Cl)c2=O)cc1',
#  'CCOc1cc(/C=C\\[N+](=O)[O-])ccc1OCC(=O)Nc1ccccc1C',
#  'CC[C@@H](Nc1cc(CN2CC(C(=O)O)C2)c(Cl)cn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC(C(=O)O)C2)c(F)cn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC(C(=O)O)C2)ccc1F)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC(C(=O)O)C2)ccn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CCC(C)(C(=O)O)C2)c(Cl)cn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC[C@@H](C(=O)O)C2)c(C)cn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC[C@@H](C(=O)O)C2)c(Cl)cn1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC[C@@H](C(=O)O)C2)c(Cl)cn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CN2CC[C@@H](C(=O)O)C2)ccc1F)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cc(CNCCC(=O)O)c(Cl)cn1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN(C)CCC(=O)O)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC(C(=O)O)C2)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC(C(=O)O)C2)c1C)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC(C)(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC[C@@H](C(=O)O)C2)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC[C@@H](C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CN2CC[C@@H](C(=O)O)C2)c1C)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CNCC(C)(C)C(=O)O)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CNCCC(=O)O)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CNC[C@@H](C)C(=O)O)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(C)c(CNC[C@H](C)C(=O)O)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(Cl)c(CN2CC(C(=O)O)C2)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(Cl)c(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(Cl)c(CN2CC(C)(C(=O)O)C2)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(Cl)c(CN2CC[C@@H](C(=O)O)C2)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(Cl)c(CN2CC[C@@H](C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccc(Cl)c(CNCCC(=O)O)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(C(C)N2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC(C(=O)O)C2)c1)c1cc(C)c(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC(C(=O)O)C2)c1)c1ccc2c(Cl)cccc2c1',
#  'CC[C@@H](Nc1cccc(CN2CC(C(=O)O)C2)c1F)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC(C(=O)O)C2)n1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC(C)(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC[C@@H](C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1cccc(CN2CC[C@@H](C(=O)O)C2)c1F)c1ccc(Cl)c(C)c1',
#  'CC[C@@H](Nc1ccnc(CN2CC(C(=O)O)C2)c1)c1ccc(Cl)c(C)c1',
#  'CCc1ccc(N[C@@H](c2ccc(Cl)c(C)c2)C(F)(F)F)cc1CN1CC(C(=O)O)C1',
#  'CCc1ccc(N[C@@H](c2ccc(Cl)c(C)c2)C(F)(F)F)cc1CN1CC[C@@H](C(=O)O)C1',
#  'CCc1ccc(N[C@H](CC)c2ccc(Cl)c(C)c2)cc1CN1CC(C(=O)O)C1',
#  'CCc1ccc(N[C@H](CC)c2ccc(Cl)c(C)c2)cc1CN1CC[C@@H](C(=O)O)C1',
#  'CCc1ccc2c(c1)/C(=C/C(=O)c1cccs1)C(=O)N2',
#  'CCc1ccccc1NC(=O)CN(C)C(=O)Cn1ncc(Cl)c(Cl)c1=O',
#  'CCn1c(Cl)c(C=O)s/c1=N\\S(=O)(=O)c1ccccc1',
#  'CCn1c(OC)nnc1[C@@H](C)NS(=O)(=O)c1ccc(F)c(Cl)c1',
#  'CN(C(=O)Cc1cnc[nH]1)[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1',
#  'CN(C(=O)[C@H](COCc1ccccc1)NC(=O)Cc1cnc[nH]1)c1ccc(Oc2ccccc2)cc1',
#  'CN(C)c1cc(NC(=O)Nc2ccccc2)c2ccccc2n1',
#  'CN(C)c1cccc2c1c(NC(=O)Nc1ccc(OCc3ccccc3)cc1)nn2C',
#  'CN(CC(=O)NC(COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1)C(=O)c1ccccc1',
#  'CN(CC(=O)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1)C(=O)c1ccccc1',
#  'CN(CCC#N)C(=O)COC(=O)c1ccccc1C(=O)c1ccc(Cl)c([N+](=O)[O-])c1',
#  'CN(c1ccccc1)c1ccc(/C=C/[N+](=O)[O-])cc1',
#  'CN1/C(=C/C(=O)c2nc(S(C)(=O)=O)ncc2Cl)C(C)(C)c2ccccc21',
#  'CN[C@H]1C[C@H]2O[C@@](C)([C@H]1OC)n1c3ccccc3c3c4c(c5c6ccccc6n2c5c31)C(=O)NC4',
#  'COC(=O)C1CN(C#N)N(c2ccc(Cl)cc2)C12c1ccccc1-c1ccccc12',
#  'COC(=O)CCS(=O)(=O)c1nc(-c2ccccc2)cc(C(F)(F)F)n1',
#  'COC(=O)C[C@]1(C(=O)OC)CN(C#N)N(c2ccc(Cl)cc2)C12c1ccccc1-c1ccccc12',
#  'COC(=O)c1ccc2c(c1)C(C)(C)C(/C=C/c1ccc(O)cc1)=[N+]2C.[I-]',
#  'COC(=O)c1ccc2c(c1)C(C)(C)C(/C=C/c1ccccc1O)=[N+]2C.[I-]',
#  'COC(CNC(=O)c1ccc2c3c(onc13)-c1ccccc1C2=O)OC',
#  'COc1cc(/C=C(/C)[N+](=O)[O-])ccc1OCc1ccccc1Cl',
#  'COc1ccc(-n2ncc(Cl)c(Cl)c2=O)cc1',
#  'COc1ccc(C(=O)/C(=C\\c2ccco2)N2C=CC=CC2=C(C#N)C#N)cc1',
#  'COc1ccc(CS(=O)(=O)/C(Cl)=C(/Cl)C(=O)Nc2ccc(OC)nc2)cc1',
#  'COc1ccc(NC(=O)/C(Cl)=C(/Cl)S(=O)(=O)Cc2ccc(C)cc2)cn1',
#  'COc1ccc(NC(=O)/C(Cl)=C(/Cl)S(=O)(=O)Cc2ccccc2)cn1',
#  'COc1ccc(NC(=O)/C(Cl)=C(/Cl)[S+]([O-])Cc2ccc(C)cc2)cn1',
#  'COc1ccc(OC)c2c1C(=O)C(Cl)=C(Cl)C2=O',
#  'COc1ccc(Oc2cc(NC(=O)c3nn(C)cc3[N+](=O)[O-])cc([N+](=O)[O-])c2)cc1',
#  'COc1ccc([N+](=O)[O-])c(S(=O)(=O)c2ccc(Cl)cc2)n1',
#  'COc1ccc([N+](=O)[O-])c(S(=O)(=O)c2ccccc2)n1',
#  'COc1cccc(-n2nnnc2S(C)(=O)=O)c1',
#  'COc1cccc(C)c1NC(=O)c1ccc(-c2cc(Cl)ccc2Cl)o1',
#  'CS(=O)(=O)c1nc(-c2ccccc2)cc(C(F)(F)F)n1',
#  'CS(=O)(=O)c1nc(-c2cccs2)cc(C(F)(F)F)n1',
#  'C[C@H](NC(=O)Cc1cnc[nH]1)C(=O)Nc1ccc(Oc2ccc(Cl)cc2)cc1',
#  'Cc1c(/C=N/Nc2nc3ccccc3[nH]2)c2ccccc2n1C',
#  'Cc1cc(C(C)Nc2cccc(CN3CC(C(=O)O)C3)c2)ccc1Cl',
#  'Cc1cc(C(Nc2ccc(C(F)(F)F)c(CN3CC(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc(C(Nc2cccc(CN3CC(C(=O)O)C3)c2)C(C)C)ccc1Cl',
#  'Cc1cc(NC(=O)c2ccc([N+](=O)[O-])o2)ccc1NC(=O)c1ccco1',
#  'Cc1cc(OCc2ccc(Cl)c(Cl)c2)ccc1CN1CC(C(=O)O)C1',
#  'Cc1cc(OCc2cccc(C(F)(F)F)c2)ccc1CN1CC(C(=O)O)C1',
#  'Cc1cc(OCc2ccccc2)ccc1CN1CC(C(=O)O)C1',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N(C)[C@@H](C)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N(C)[C@@H](CCN(C)C)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N(C)[C@@H](CN(C)C)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N(C)[C@H](CCN(C)C)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N[C@@H](C)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N[C@@H](CCN(C)C)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc(S(=O)(=O)Nc2cccc(-c3cc(C)c(C(=O)N[C@@H](CCN)C(=O)O)c(C)c3)c2)c(C)cc1Cl',
#  'Cc1cc([C@@H](C)Nc2ccc(Cl)c(CN3CC[C@@H](C(=O)O)C3)c2)cc(C)c1Cl',
#  'Cc1cc([C@@H](C)Nc2cccc(-c3cc(C)c(C(=O)N[C@@H](C)C(=O)O)c(C)c3)c2)ccc1Cl',
#  'Cc1cc([C@H](Nc2cc(CN3CC[C@@H](C(=O)O)C3)c(Cl)cn2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2cc(CNCCC(=O)O)c(Cl)cn2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(C)c(CN3CC(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(C)c(CN3CC(C(=O)O)C3)c2C)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(C)c(CN3CCC(C)(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(C)c(CN3CC[C@@H](C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(C)c(CN3CC[C@@H](C(=O)O)C3)c2C)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(C)c(CNCCC(=O)O)c2C)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CN3CC(C(=O)O)C3)c2)C(C)C)cc(C)c1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CN3CC(C(=O)O)C3)c2)C(C)C)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CN3CC(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CN3CC(C)(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CN3CCC(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CN3CC[C@@H](C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(Cl)c(CNCCC(=O)O)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2ccc(F)c(CN3CC(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2cccc(CN3CC(C(=O)O)C3)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2cccc(CN3CC(C(=O)O)C3)c2)C2CCC2)ccc1Cl',
#  'Cc1cc([C@H](Nc2cccc(CN3CC(C(=O)O)C3)c2C)C(F)(F)F)ccc1Cl',
#  'Cc1cc([C@H](Nc2cccc([C@H](C)NCCC(=O)O)c2)C(F)(F)F)ccc1Cl',
#  'Cc1cc([N+](=O)[O-])c2ccccc2[n+]1[O-]',
#  'Cc1ccc(-c2nc(NC(=O)c3nn(C)cc3[N+](=O)[O-])sc2C)cc1',
#  'Cc1ccc(-c2nc(NC(=O)c3nn(C)cc3[N+](=O)[O-])sc2C)cc1C',
#  'Cc1ccc(C(=O)OCn2ncc(Cl)c(Cl)c2=O)cc1',
#  'Cc1ccc(C)c(C(=O)Cn2ncc(Cl)c(Cl)c2=O)c1',
#  'Cc1ccc(NC(=O)C2=C(c3ccccc3)S(=O)(=O)CCS2(=O)=O)cc1',
#  'Cc1ccc(N[C@H](C)c2cc(C)c(Cl)c(C)c2)cc1CN1CC[C@@H](C(=O)O)C1',
#  'Cc1ccc(N[C@H](C)c2cc(C)c(Cl)c(C)c2)cc1CNCCC(=O)O',
#  'Cc1ccc(Nc2cc(C)nn2-c2nc(C)cc(O)n2)cc1',
#  'Cc1ccc(S(=O)(=O)Nc2cccc3cccnc23)cc1',
#  'Cc1ccc(S(=O)(=O)Nc2cccc3ncccc23)s1',
#  'Cc1ccccc1CS(=O)(=O)c1nnc([C@H](CC(C)C)NC(=O)OC(C)(C)C)o1',
#  'Cc1ccnc(N2C(=O)c3cccc4c([N+](=O)[O-])ccc(c34)C2=O)c1',
#  'Cc1oc2c(c1C(=O)NCc1cccnc1)C(=O)c1ccccc1C2=O',
#  'Cn1cnc(CC(=O)N[C@@H](COCc2ccccc2)C(=O)Nc2ccc(Oc3ccccc3)cc2)c1',
#  'Cn1nc(-c2ccc(Cl)cc2)nc2c(=O)n(C)c(=O)nc1-2',
#  'NC(=S)c1cn([C@@H]2O[C@H](CO)[C@@H](O)[C@H]2O)c2ncnc(N)c12',
#  'O=C(/C(=C/c1ccc(Cl)cc1)c1nc2ccccc2[nH]1)c1cccs1',
#  'O=C(/C=C/c1ccccc1)CC(O)(c1ccccc1)C(F)(F)C(F)F',
#  'O=C(/C=C/c1ccccc1)CC(O)(c1ccccc1)C(F)(F)F',
#  'O=C(CCCC(=O)c1cccs1)NC(CNc1ccc(Oc2ccccc2)cc1)COCc1ccccc1',
#  'O=C(CCl)Nc1cc(SCC(O)CO)cc([N+](=O)[O-])c1',
#  'O=C(Cc1ccccc1F)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](CCCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Nc2ccccc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(OC2CCCCC2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(OCc2ccccc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccc(Cl)cc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccc(F)cc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2cccc(Cl)c2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)c(Cl)c1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](COCc1ccccc1)c1nc2cc(Oc3ccc(F)cc3)ccc2[nH]1',
#  'O=C(Cc1cnc[nH]1)N[C@@H](Cc1ccccc1)C(=O)Nc1ccc(Oc2ccc(Cl)cc2)cc1',
#  'O=C(Cn1ncc(Cl)c(Cl)c1=O)N1CCN(Cc2ccccc2)CC1',
#  'O=C(Cn1ncc(Cl)c(Cl)c1=O)N1CCN(S(=O)(=O)c2ccc3ccccc3c2)CC1',
#  'O=C(Cn1ncc(Cl)c(Cl)c1=O)N1CCc2ccccc21',
#  'O=C(Cn1ncc(Cl)c(Cl)c1=O)c1ccc(Cl)cc1',
#  'O=C(NC(COCc1ccccc1)C(=O)Nc1ccc(Oc2ccccc2)cc1)C1CC1',
#  'O=C(NCc1cccnc1)/C(=C\\c1ccc(-c2ccc(Cl)c(Cl)c2)o1)S(=O)(=O)c1ccccc1',
#  'O=C(Nc1ccc(N2CCN(C(=O)c3ccccc3)CC2)cc1)c1ccc([N+](=O)[O-])o1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1CN(Cc2ccccc2)CCN1C(=O)Cc1cnc[nH]1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](Cc2ccc(F)cc2)CN1C(=O)Cn1ccnn1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](Cc2ccc(F)cc2)CN1C(=O)Cn1cncn1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](Cc2ccc(F)cc2)CN1C(=O)Cn1nccn1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](Cc2ccccc2)CN1C(=O)Cc1cnc[nH]1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](Cc2ccccc2)CN1C(=O)Cn1cncn1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](c2ccccc2)CN1C(=O)Cc1cnc[nH]1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@@H](c2ccccc2)CN1C(=O)Cn1cncn1',
#  'O=C(Nc1ccc(Oc2ccc(F)cc2)cc1)[C@@H]1C[C@H](Cc2ccc(F)cc2)CN1C(=O)Cn1cncn1',
#  'O=C(Nc1ccccc1)c1nnsc1S(=O)(=O)c1ccc(Cl)cc1',
#  'O=C(Nc1ccccc1Cl)/C(Cl)=C(\\Cl)[S+]([O-])c1ccccc1',
#  'O=C(O)C1CN(Cc2ccc(OCc3ccc(Cl)c(Cl)c3)c(F)c2)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3ccc(Cl)c(Cl)c3)cc2)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3ccc(Cl)c(Cl)c3)cc2F)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3cccc(C(F)(F)F)c3)c(Cl)c2)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3cccc(C(F)(F)F)c3)c(F)c2)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3cccc(C(F)(F)F)c3)cc2)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3cccc(C(F)(F)F)c3)cc2Cl)C1',
#  'O=C(O)C1CN(Cc2ccc(OCc3cccc(C(F)(F)F)c3)cc2F)C1',
#  'O=C(OCn1ncc(Br)c(Br)c1=O)c1c(F)cccc1F',
#  'O=C(OCn1ncc(Br)c(Br)c1=O)c1ccc(F)cc1',
#  'O=C(OCn1ncc(Br)c(Br)c1=O)c1ccccc1Cl',
#  'O=C1C(=O)c2ccccc2-c2ccccc21',
#  'O=C1C(Nc2ccc(O)cc2)=C/C(=N/S(=O)(=O)c2cccs2)c2ccccc21',
#  'O=C1C=C(c2ccc(Cl)cc2)C(=O)N1Nc1ccccc1',
#  'O=C1CN(C(=O)Cn2ncc(Cl)c(Cl)c2=O)c2ccccc2N1',
#  'O=C1c2cccc3c([N+](=O)[O-])ccc(c23)C(=O)N1CC1CCCO1',
#  'O=C1c2cccc3c([N+](=O)[O-])ccc(c23)C(=O)N1c1ccccn1',
#  'O=S(=O)(c1ccc(Cl)c(Cl)c1)c1snnc1-c1ccccc1',
#  'O=S1(=O)C=C(Sc2nc3ccccc3s2)c2ccccc21',
#  'O=[N+]([O-])c1cc(S(=O)(=O)C(F)(F)F)ccc1Sc1nc2ccccc2[nH]1',
#  'O=[N+]([O-])c1cnc(Sc2ccncn2)s1',
#  'O=c1c(Cl)c(Cl)cnn1-c1ccccc1',
#  'Oc1c(C(c2ccccc2Cl)N2CCCC2)ccc2cccnc12'}
